# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import torch
from torch.utils.tensorboard import SummaryWriter
import time
from datetime import datetime
import os

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
# Out:
# Using device: cuda

# %%
df = sns.load_dataset("titanic")

# %%
## Randomly select a fraction of the dataset
FRACTION = 0.8

train_df = df.sample(frac=FRACTION, random_state=42) # fix seed for reproducibility
# Get the remaining 20% of rows for the test set
# This is achieved by selecting rows whose index is not present in the training set
test_df = df.drop(train_df.index)
# Display the shapes of the resulting DataFrames
print(f"Shape of training DataFrame: {train_df.shape}")
print(f"Shape of test DataFrame: {test_df.shape}")

# You can now save these DataFrames if needed
train_df.to_csv('train_data.csv', index=False)
test_df.to_csv('test_data.csv', index=False)
# Out:
# Shape of training DataFrame: (713, 15)
# Shape of test DataFrame: (178, 15)

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
(df.isnull().sum() / len(df)) * 100
# Out:
# survived        0.000000
# pclass          0.000000
# sex             0.000000
# age            19.865320
# sibsp           0.000000
# parch           0.000000
# fare            0.000000
# embarked        0.224467
# class           0.000000
# who             0.000000
# adult_male      0.000000
# deck           77.216611
# embark_town     0.224467
# alive           0.000000
# alone           0.000000
# dtype: float64

# %%
# Get the data types of all columns
column_dtypes = df.dtypes
print(column_dtypes)
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
# sns.heatmap(df.isnull(), cbar=False, yticklabels=False)
# plt.title("Missing Data Heatmap")
# plt.show()

# %%
## Drop columns with missing value and alive column
df_nomissing = df.drop(columns=['age', 'deck', 'embarked', 'embark_town', 'survived',])

# %%
df_nomissing.head()
# Out:
#    pclass     sex  sibsp  parch     fare  class    who  adult_male alive  \
# 0       3    male      1      0   7.2500  Third    man        True    no
# 1       1  female      1      0  71.2833  First  woman       False   yes
# 2       3  female      0      0   7.9250  Third  woman       False   yes
# 3       1  female      1      0  53.1000  First  woman       False   yes
# 4       3    male      0      0   8.0500  Third    man        True    no
#
#    alone
# 0  False
# 1  False
# 2   True
# 3  False
# 4   True

# %%
# Normalize numeric feature
from sklearn.preprocessing import StandardScaler
num_cols = ["fare", "sibsp", "parch"]
scaler = StandardScaler()
df_nomissing[num_cols] = scaler.fit_transform(df_nomissing[num_cols])

# %%
#Convert categorial features to integers using Label Encoding
from sklearn.preprocessing import LabelEncoder

cat_cols = ["pclass", "sex", "class", "who", "adult_male", "alive", "alone"]  # treat pclass as categorical
label_encoders = {}

for col in cat_cols:
    le = LabelEncoder()
    df_nomissing[col] = le.fit_transform(df_nomissing[col])
    label_encoders[col] = le

# %%
df_nomissing
# Out:
#      pclass  sex     sibsp     parch      fare  class  who  adult_male  alive  \
# 0         2    1  0.432793 -0.473674 -0.502445      2    1           1      0
# 1         0    0  0.432793 -0.473674  0.786845      0    2           0      1
# 2         2    0 -0.474545 -0.473674 -0.488854      2    2           0      1
# 3         0    0  0.432793 -0.473674  0.420730      0    2           0      1
# 4         2    1 -0.474545 -0.473674 -0.486337      2    1           1      0
# ..      ...  ...       ...       ...       ...    ...  ...         ...    ...
# 886       1    1 -0.474545 -0.473674 -0.386671      1    1           1      0
# 887       0    0 -0.474545 -0.473674 -0.044381      0    2           0      1
# 888       2    0  0.432793  2.008933 -0.176263      2    2           0      0
# 889       0    1 -0.474545 -0.473674 -0.044381      0    1           1      1
# 890       2    1 -0.474545 -0.473674 -0.492378      2    1           1      0
#
#      alone
# 0        0
# 1        0
# 2        1
# 3        0
# 4        1
# ..     ...
# 886      1
# 887      1
# 888      0
# 889      1
# 890      1
#
# [891 rows x 10 columns]

# %%
## Randomly select a fraction of the dataset
FRACTION = 0.8

train_df_nomissing = df_nomissing.sample(frac=FRACTION, random_state=42) # fix seed for reproducibility
# Get the remaining 20% of rows for the test set
# This is achieved by selecting rows whose index is not present in the training set
test_df_nomissing = df_nomissing.drop(train_df_nomissing.index)
# Display the shapes of the resulting DataFrames
print(f"Shape of training DataFrame: {train_df_nomissing.shape}")
print(f"Shape of test DataFrame: {test_df_nomissing.shape}")

# You can now save these DataFrames if needed
train_df_nomissing.to_csv('train_data_nomissing_std.csv', index=False)
test_df_nomissing.to_csv('test_data_nomissing_std.csv', index=False)
# Out:
# Shape of training DataFrame: (713, 10)
# Shape of test DataFrame: (178, 10)

# %%
X_train = train_df_nomissing.values.astype("float32")
X_test = test_df_nomissing.values.astype("float32")

# %% [markdown]
# # PyTorch Dataset for loading data to training loop

# %%
from torch.utils.data import Dataset, DataLoader

class TitanicAutoencoderDataset(Dataset):
    def __init__(self, X):
        self.X = torch.tensor(X, dtype=torch.float32)

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        return self.X[idx], self.X[idx]  # input = target

train_ds = TitanicAutoencoderDataset(X_train)
test_ds = TitanicAutoencoderDataset(X_test)

# train_loader = DataLoader(train_ds, batch_size=64, shuffle=True)
# test_loader = DataLoader(test_ds, batch_size=64)

# %% [markdown]
# # Autoencoder model

# %%
import torch.nn as nn

class TitanicAutoencoder(nn.Module):
    def __init__(self, input_dim, latent_dim=4):
        super().__init__()
        self.encoder = nn.Sequential(
            nn.Linear(input_dim, 16),
            nn.ReLU(),
            nn.Linear(16, latent_dim)
        )
        self.decoder = nn.Sequential(
            nn.Linear(latent_dim, 16),
            nn.ReLU(),
            nn.Linear(16, input_dim)
        )

    def forward(self, x):
        z = self.encoder(x)       # compressed embedding
        x_recon = self.decoder(z) # reconstructed input
        return x_recon

    def encode(self, x):
        return self.encoder(x)    # get embedding only

# %%
def plot_loss_curve(train_losses, test_losses):
    fig, ax = plt.subplots(figsize=(8, 5))
    ax.plot(train_losses, label="Train Loss", marker='o')
    ax.plot(test_losses, label="Test Loss", marker='x')
    ax.set_xlabel("Epoch")
    ax.set_ylabel("Loss")
    ax.set_title("Train vs Test Loss")
    ax.legend()
    ax.grid(True)
    return fig

# %%
import subprocess

def get_gpu_utilization():
    result = subprocess.run(
        ['nvidia-smi', '--query-gpu=utilization.gpu,memory.used',
         '--format=csv,nounits,noheader'],
        stdout=subprocess.PIPE,
        text=True
    )
    gpu_util, mem_used = map(int, result.stdout.strip().split(','))
    return gpu_util, mem_used

# %% [markdown]
# # Training loop

# %%
LATENT_DIM = 8  # Set the latent dimension for the autoencode
print(f"Using input dimension: {X_train.shape[1]}, latent dimension: {LATENT_DIM}")
model = TitanicAutoencoder(input_dim=X_train.shape[1], latent_dim=LATENT_DIM).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', patience=5, factor=0.5) 
# This will halve the learning rate if avg_test_loss doesn't improve for 5 epochs.

loss_fn = nn.MSELoss()

# Create a timestamped run directory
os.makedirs("runs", exist_ok=True) # Create directories for logs and checkpoints
RUN_NAME = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
LOG_DIR = f"runs/autoencoder_{RUN_NAME}" # Create directories for logs and checkpoints
CHECKPOINT_DIR = f"checkpoints_{RUN_NAME}" # Create directories for logs and checkpoints
os.makedirs(CHECKPOINT_DIR, exist_ok=True) # Create directories if they don't exist
BATCH_SIZE = 256 # Adjust batch size as needed
WORKERS = 1 # Number of workers for DataLoader, adjust based on your system

writer = SummaryWriter(log_dir=LOG_DIR)

#Training loop
# Prepare training and test datasets
train_ds = TitanicAutoencoderDataset(X_train)
test_ds = TitanicAutoencoderDataset(X_test)
train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, num_workers=WORKERS, shuffle=True)
test_loader = DataLoader(test_ds, batch_size=BATCH_SIZE, num_workers=WORKERS)

# Track losses
train_losses = []
test_losses = []
best_loss = float('inf') # Initialize best_loss for comparison and checkpointing
# Training loop
num_epochs = 500
for epoch in range(num_epochs):
    start_time = time.time()
    model.train()
    train_loss = 0.0

    for x, y in train_loader:
        x = x.to(device)
        y = y.to(device)

        recon = model(x)
        loss = loss_fn(recon, y)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        train_loss += loss.item()

    avg_train_loss = train_loss / len(train_loader)
    train_losses.append(avg_train_loss)

    end_time = time.time()
    epoch_duration = end_time - start_time
    # GPU metrics
    gpu_alloc = torch.cuda.memory_allocated() / 1024**2 # Convert to MB
    gpu_reserved = torch.cuda.memory_reserved() / 1024**2 # Convert to MB
    writer.add_scalar("GPU/Memory_Allocated_MB", gpu_alloc, epoch)
    writer.add_scalar("GPU/Memory_Reserved_MB", gpu_reserved, epoch)

    try:
        gpu_util, mem_used = get_gpu_utilization()
        writer.add_scalar("GPU/Utilization_%", gpu_util, epoch)
        writer.add_scalar("GPU/Memory_Used_MB", mem_used, epoch)
    except:
        pass  # In case nvidia-smi isn't available

    # Evaluate on test set
    model.eval()
    test_loss = 0.0
    with torch.no_grad():
        for x, y in test_loader:
            x = x.to(device)
            y = y.to(device)
            recon = model(x)
            loss = loss_fn(recon, y)
            test_loss += loss.item()

    avg_test_loss = test_loss / len(test_loader)
    test_losses.append(avg_test_loss)

    # ✅ Log scalar losses
    writer.add_scalar("Loss/train", avg_train_loss, epoch)
    writer.add_scalar("Loss/test", avg_test_loss, epoch)
    writer.add_figure("Loss Overlap Curve", plot_loss_curve(train_losses, test_losses), global_step=epoch)

    # ✅ Log weights and gradients
    for name, param in model.named_parameters():
        writer.add_histogram(f"Weights/{name}", param, epoch)
        if param.grad is not None:
            writer.add_histogram(f"Gradients/{name}", param.grad, epoch)

    # ✅ Log activation from encoder
    with torch.no_grad():
        activation_sample = torch.tensor(X_train[:1], dtype=torch.float32).to(device)
        encoded = model.encoder(activation_sample)
        writer.add_histogram("Activations/EncoderOutput", encoded, epoch)
        current_lr = optimizer.param_groups[0]['lr']
        writer.add_scalar("LR", current_lr, epoch)

    print(f"Epoch {epoch+1:2d} | Train Loss: {avg_train_loss:.4f} | Test Loss: {avg_test_loss:.4f} | LR: {current_lr:.6f} | Time: {epoch_duration:.2f} sec")

    # Save only the best model based on test loss
    if avg_test_loss < best_loss:
        best_loss = avg_test_loss
        print(f"New best model found at epoch {epoch+1}, saving checkpoint...")
        
            # Save the model state
        torch.save({
            'epoch': epoch,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'scheduler_state_dict': scheduler.state_dict(),
            'train_losses': train_losses,
            'test_losses': test_losses,
            'input_dim': X_train.shape[1],           # ✅ Save architecture args
            'latent_dim': LATENT_DIM 
            }, f"{CHECKPOINT_DIR}/autoencoder_epoch{epoch+1}.pt")
    
    scheduler.step(avg_test_loss) # Adjust learning rate based on test loss

# ✅ After training — log embeddings to projector
with torch.no_grad():
    sample_input = torch.tensor(X_test[:500], dtype=torch.float32).to(device)
    latent_vectors = model.encoder(sample_input)
    metadata = [f"Passenger {i}" for i in range(sample_input.shape[0])]
    writer.add_embedding(latent_vectors, metadata=metadata, tag="LatentEmbeddings", global_step=num_epochs)
    
writer.close()
# Out:
# Using input dimension: 10, latent dimension: 8
# Epoch  1 | Train Loss: 1.2075 | Test Loss: 1.1382 | LR: 0.001000 | Time: 0.17 sec
# New best model found at epoch 1, saving checkpoint...
# Epoch  2 | Train Loss: 1.1825 | Test Loss: 1.1161 | LR: 0.001000 | Time: 0.05 sec
# New best model found at epoch 2, saving checkpoint...
# Epoch  3 | Train Loss: 1.1610 | Test Loss: 1.0946 | LR: 0.001000 | Time: 0.05 sec
# New best model found at epoch 3, saving checkpoint...
# Epoch  4 | Train Loss: 1.1396 | Test Loss: 1.0732 | LR: 0.001000 | Time: 0.05 sec
# New best model found at epoch 4, saving checkpoint...
# Epoch  5 | Train Loss: 1.1203 | Test Loss: 1.0526 | LR: 0.001000 | Time: 0.05 sec
# New best model found at epoch 5, saving checkpoint...
# Epoch  6 | Train Loss: 1.1073 | Test Loss: 1.0323 | LR: 0.001000 | Time: 0.05 sec
# New best model found at epoch 6, saving checkpoint...
# Epoch  7 | Train Loss: 1.0871 | Test Loss: 1.0120 | LR: 0.001000 | Time: 0.06 sec
# New best model found at epoch 7, saving checkpoint...
# Epoch  8 | Train Loss: 1.0602 | Test Loss: 0.9914 | LR: 0.001000 | Time: 0.05 sec
# New best model found at epoch 8, saving checkpoint...
# Epoch  9 | Train Loss: 1.0358 | Test Loss: 0.9731 | LR: 0.001000 | Time: 0.05 sec
# New best model found at epoch 9, saving checkpoint...
# Epoch 10 | Train Loss: 1.0163 | Test Loss: 0.9549 | LR: 0.001000 | Time: 0.05 sec
# New best model found at epoch 10, saving checkpoint...
# Epoch 11 | Train Loss: 1.0016 | Test Loss: 0.9361 | LR: 0.001000 | Time: 0.05 sec
# New best model found at epoch 11, saving checkpoint...
# Epoch 12 | Train Loss: 0.9832 | Test Loss: 0.9163 | LR: 0.001000 | Time: 0.05 sec
# New best model found at epoch 12, saving checkpoint...
# Epoch 13 | Train Loss: 0.9658 | Test Loss: 0.8939 | LR: 0.001000 | Time: 0.05 sec
# New best model found at epoch
| LR: 0.001000 | Time: 0.06 sec
# New best model found at epoch 251, saving checkpoint...
# Epoch 252 | Train Loss: 0.0221 | Test Loss: 0.0190 | LR: 0.001000 | Time: 0.07 sec
# New best model found at epoch 252, saving checkpoint...
# Epoch 253 | Train Loss: 0.0220 | Test Loss: 0.0190 | LR: 0.001000 | Time: 0.07 sec
# New best model found at epoch 253, saving checkpoint...
# Epoch 254 | Train Loss: 0.0220 | Test Loss: 0.0189 | LR: 0.001000 | Time: 0.07 sec
# New best model found at epoch 254, saving checkpoint...
# Epoch 255 | Train Loss: 0.0219 | Test Loss: 0.0189 | LR: 0.001000 | Time: 0.07 sec
# New best model found at epoch 255, saving checkpoint...
# Epoch 256 | Train Loss: 0.0216 | Test Loss: 0.0188 | LR: 0.001000 | Time: 0.07 sec
# New best model found at epoch 256, saving checkpoint...
# Epoch 257 | Train Loss: 0.0216 | Test Loss: 0.0188 | LR: 0.001000 | Time: 0.07 sec
# New best model found at epoch 257, saving checkpoint...
# Epoch 258 | Train Loss: 0.0217 | Test Loss: 0.0187 | LR: 0.001000 | Time: 0.07 sec
# New best model found at epoch 258, saving checkpoint...
# Epoch 259 | Train Loss: 0.0216 | Test Loss: 0.0186 | LR: 0.001000 | Time: 0.07 sec
# New best model found at epoch 259, saving checkpoint...
# Epoch 260 | Train Loss: 0.0215 | Test Loss: 0.0185 | LR: 0.001000 | Time: 0.07 sec
# New best model found at epoch 260, saving checkpoint...
# Epoch 261 | Train Loss: 0.0214 | Test Loss: 0.0185 | LR: 0.001000 | Time: 0.06 sec
# New best model found at epoch 261, saving checkpoint...
# Epoch 262 | Train Loss: 0.0214 | Test Loss: 0.0184 | LR: 0.001000 | Time: 0.07 sec
# New best model found at epoch 262, saving checkpoint...
# Epoch 263 | Train Loss: 0.0214 | Test Loss: 0.0184 | LR: 0.001000 | Time: 0.07 sec
# New best model found at epoch 263, saving checkpoint...
# Epoch 264 | Train Loss: 0.0211 | Test Loss: 0.0183 | LR: 0.001000 | Time: 0.07 sec
# New best model found at epoch 264, saving checkpoint...
# Epoch 265 | Train Loss: 0.0210 | Test Loss: 0.0182 | LR: 0.001000 | Time: 0.07 sec
# New best model found at epoch 265, saving checkpoint...
# Epoch 266 | Train Loss: 0.0211 | Test Loss: 0.0182 | LR: 0.001000 | Time: 0.07 sec
# New best model found at epoch 266, saving checkpoint...
# Epoch 267 | Train Loss: 0.0210 | Test Loss: 0.0181 | LR: 0.001000 | Time: 0.07 sec
# New best model found at epoch 267, saving checkpoint...
# Epoch 268 | Train Loss: 0.0208 | Test Loss: 0.0181 | LR: 0.001000 | Time: 0.07 sec
# New best model found at epoch 268, saving checkpoint...
# Epoch 269 | Train Loss: 0.0207 | Test Loss: 0.0180 | LR: 0.001000 | Time: 0.07 sec
# New best model found at epoch 269, saving checkpoint...
# Epoch 270 | Train Loss: 0.0208 | Test Loss: 0.0180 | LR: 0.001000 | Time: 0.07 sec
# New best model found at epoch 270, saving checkpoint...
# Epoch 271 | Train Loss: 0.0206 | Test Loss: 0.0179 | LR: 0.001000 | Time: 0.07 sec
# New best model found at epoch 271, saving checkpoint...
# Epoch 272 | Train Loss: 0.0205 | Test Loss: 0.0178 | LR: 0.001000 | Time: 0.08 sec
# New best model found at epoch 272, saving checkpoint...
# Epoch 273 | Train Loss: 0.0204 | Test Loss: 0.0177 | LR: 0.001000 | Time: 0.07 sec
# New best model found at epoch 273, saving checkpoint...
# Epoch 274 | Train Loss: 0.0202 | Test Loss: 0.0177 | LR: 0.001000 | Time: 0.06 sec
# New best model found at epoch 274, saving checkpoint...
# Epoch 275 | Train Loss: 0.0202 | Test Loss: 0.0176 | LR: 0.001000 | Time: 0.07 sec
# New best model found at epoch 275, saving checkpoint...
# Epoch 276 | Train Loss: 0.0203 | Test Loss: 0.0176 | LR: 0.001000 | Time: 0.07 sec
# New best model found at epoch 276, saving checkpoint...
# Epoch 277 | Train Loss: 0.0202 | Test Loss: 0.0175 | LR: 0.001000 | Time: 0.07 sec
# New best model found at epoch 277, saving checkpoint...
# Epoch 278 | Train Loss: 0.0201 | Test Loss: 0.0175 | LR: 0.001000 | Time: 0.07 sec
# New best model found at epoch 278, saving checkpoint...
# Epoch 279 | Train Loss: 0.0199 | Test Loss: 0.0174 | LR: 0.001000 | Time: 0.06 sec
# New best model found at epoch 279, saving checkpoint...
# Epoch 280 | Train Loss: 0.0197 | Test Loss: 0.0173 | LR: 0.001000 | Time: 0.07 sec
# New best model found at epoch 280, saving checkpoint...
# Epoch 281 | Train Loss: 0.0198 | Test Loss: 0.0173 | LR: 0.001000 | Time: 0.07 sec
# New best model found at epoch 281, saving checkpoint...
# Epoch 282 | Train Loss: 0.0197 | Test Loss: 0.0172 | LR: 0.001000 | Time: 0.07 sec
# New best model found at epoch 282, saving checkpoint...
# Epoch 283 | Train Loss: 0.0195 | Test Loss: 0.0171 | LR: 0.001000 | Time: 0.07 sec
# New best model found at epoch 283, saving checkpoint...
# Epoch 284 | Train Loss: 0.0196 | Test Loss: 0.0171 | LR: 0.001000 | Time: 0.07 sec
# New best model found at epoch 284, saving checkpoint...
# Epoch 285 | Train Loss: 0.0194 | Test Loss: 0.0170 | LR: 0.001000 | Time: 0.07 sec
# New best model found at epoch 285, saving checkpoint...
# Epoch 286 | Train Loss: 0.0194 | Test Loss: 0.0169 | LR: 0.001000 | Time: 0.07 sec
# New best model found at epoch 286, saving checkpoint...
# Epoch 287 | Train Loss: 0.0194 | Test Loss: 0.0169 | LR: 0.001000 | Time: 0.07 sec
# New best model found at epoch 287, saving checkpoint...
# Epoch 288 | Train Loss: 0.0192 | Test Loss: 0.0168 | LR: 0.001000 | Time: 0.07 sec
# New best model found at epoch 288, saving checkpoint...
# Epoch 289 | Train Loss: 0.0190 | Test Loss: 0.0167 | LR: 0.001000 | Time: 0.08 sec
# New best model found at epoch 289, saving checkpoint...
# Epoch 290 | Train Loss: 0.0190 | Test Loss: 0.0167 | LR: 0.001000 | Time: 0.07 sec
# New best model found at epoch 290, saving checkpoint...
# Epoch 291 | Train Loss: 0.0188 | Test Loss: 0.0166 | LR: 0.001000 | Time: 0.07 sec
# New best model found at epoch 291, saving checkpoint...
# Epoch 292 | Train Loss: 0.0188 | Test Loss: 0.0165 | LR: 0.001000 | Time: 0.07 sec
# New best model found at epoch 292, saving checkpoint...
# New best model found at epoch 312, saving checkpoint...
# Epoch 313 | Train Loss: 0.0166 | Test Loss: 0.0148 | LR: 0.001000 | Time: 0.11 sec
# New best model found at epoch 313, saving checkpoint...
# Epoch 314 | Train Loss: 0.0166 | Test Loss: 0.0147 | LR: 0.001000 | Time: 0.11 sec
# New best model found at epoch 314, saving checkpoint...
# Epoch 315 | Train Loss: 0.0164 | Test Loss: 0.0146 | LR: 0.001000 | Time: 0.11 sec
# New best model found at epoch 315, saving checkpoint...
# Epoch 316 | Train Loss: 0.0164 | Test Loss: 0.0145 | LR: 0.001000 | Time: 0.10 sec
# New best model found at epoch 316, saving checkpoint...
# Epoch 317 | Train Loss: 0.0161 | Test Loss: 0.0144 | LR: 0.001000 | Time: 0.10 sec
# New best model found at epoch 317, saving checkpoint...
# Epoch 318 | Train Loss: 0.0159 | Test Loss: 0.0143 | LR: 0.001000 | Time: 0.10 sec
# New best model found at epoch 318, saving checkpoint...
# Epoch 319 | Train Loss: 0.0158 | Test Loss: 0.0141 | LR: 0.001000 | Time: 0.11 sec
# New best model found at epoch 319, saving checkpoint...
# Epoch 320 | Train Loss: 0.0157 | Test Loss: 0.0140 | LR: 0.001000 | Time: 0.11 sec
# New best model found at epoch 320, saving checkpoint...
# Epoch 321 | Train Loss: 0.0155 | Test Loss: 0.0139 | LR: 0.001000 | Time: 0.11 sec
# New best model found at epoch 321, saving checkpoint...
# Epoch 322 | Train Loss: 0.0154 | Test Loss: 0.0138 | LR: 0.001000 | Time: 0.11 sec
# New best model found at epoch 322, saving checkpoint...
# Epoch 323 | Train Loss: 0.0152 | Test Loss: 0.0137 | LR: 0.001000 | Time: 0.11 sec
# New best model found at epoch 323, saving checkpoint...
# Epoch 324 | Train Loss: 0.0151 | Test Loss: 0.0136 | LR: 0.001000 | Time: 0.10 sec
# New best model found at epoch 324, saving checkpoint...
# Epoch 325 | Train Loss: 0.0152 | Test Loss: 0.0135 | LR: 0.001000 | Time: 0.11 sec
# New best model found at epoch 325, saving checkpoint...
# Epoch 326 | Train Loss: 0.0149 | Test Loss: 0.0134 | LR: 0.001000 | Time: 0.10 sec
# New best model found at epoch 326, saving checkpoint...
# Epoch 327 | Train Loss: 0.0146 | Test Loss: 0.0133 | LR: 0.001000 | Time: 0.12 sec
# New best model found at epoch 327, saving checkpoint...
# Epoch 328 | Train Loss: 0.0145 | Test Loss: 0.0131 | LR: 0.001000 | Time: 0.10 sec
# New best model found at epoch 328, saving checkpoint...
# Epoch 329 | Train Loss: 0.0144 | Test Loss: 0.0130 | LR: 0.001000 | Time: 0.12 sec
# New best model found at epoch 329, saving checkpoint...
# Epoch 330 | Train Loss: 0.0143 | Test Loss: 0.0129 | LR: 0.001000 | Time: 0.12 sec
# New best model found at epoch 330, saving checkpoint...
# Epoch 331 | Train Loss: 0.0141 | Test Loss: 0.0128 | LR: 0.001000 | Time: 0.11 sec
# New best model found at epoch 331, saving checkpoint...
# Epoch 332 | Train Loss: 0.0139 | Test Loss: 0.0126 | LR: 0.001000 | Time: 0.11 sec
# New best model found at epoch 332, saving checkpoint...
# Epoch 333 | Train Loss: 0.0138 | Test Loss: 0.0125 | LR: 0.001000 | Time: 0.12 sec
# New best model found at epoch 333, saving checkpoint...
# Epoch 334 | Train Loss: 0.0136 | Test Loss: 0.0124 | LR: 0.001000 | Time: 0.15 sec
# New best model found at epoch 334, saving checkpoint...
# Epoch 335 | Train Loss: 0.0135 | Test Loss: 0.0123 | LR: 0.001000 | Time: 0.11 sec
# New best model found at epoch 335, saving checkpoint...
# Epoch 336 | Train Loss: 0.0133 | Test Loss: 0.0121 | LR: 0.001000 | Time: 0.11 sec
# New best model found at epoch 336, saving checkpoint...
# Epoch 337 | Train Loss: 0.0131 | Test Loss: 0.0120 | LR: 0.001000 | Time: 0.11 sec
# New best model found at epoch 337, saving checkpoint...
# Epoch 338 | Train Loss: 0.0128 | Test Loss: 0.0118 | LR: 0.001000 | Time: 0.10 sec
# New best model found at epoch 338, saving checkpoint...
# Epoch 339 | Train Loss: 0.0128 | Test Loss: 0.0117 | LR: 0.001000 | Time: 0.65 sec
# New best model found at epoch 339, saving checkpoint...
# Epoch 340 | Train Loss: 0.0126 | Test Loss: 0.0116 | LR: 0.001000 | Time: 0.12 sec
# New best model found at epoch 340, saving checkpoint...
# Epoch 341 | Train Loss: 0.0123 | Test Loss: 0.0114 | LR: 0.001000 | Time: 0.18 sec
# New best model found at epoch 341, saving checkpoint...
# Epoch 342 | Train Loss: 0.0122 | Test Loss: 0.0113 | LR: 0.001000 | Time: 0.11 sec
# New best model found at epoch 342, saving checkpoint...
# Epoch 343 | Train Loss: 0.0122 | Test Loss: 0.0111 | LR: 0.001000 | Time: 0.10 sec
# New best model found at epoch 343, saving checkpoint...
# Epoch 344 | Train Loss: 0.0119 | Test Loss: 0.0110 | LR: 0.001000 | Time: 0.11 sec
# New best model found at epoch 344, saving checkpoint...
# Epoch 345 | Train Loss: 0.0117 | Test Loss: 0.0109 | LR: 0.001000 | Time: 0.11 sec
# New best model found at epoch 345, saving checkpoint...
# Epoch 346 | Train Loss: 0.0116 | Test Loss: 0.0107 | LR: 0.001000 | Time: 0.11 sec
# New best model found at epoch 346, saving checkpoint...
# ...
# New best model found at epoch 384, saving checkpoint...
# Epoch 385 | Train Loss: 0.0056 | Test Loss: 0.0053 | LR: 0.001000 | Time: 0.12 sec
# New best model found at epoch 385, saving checkpoint...
# Epoch 386 | Train Loss: 0.0055 | Test Loss: 0.0052 | LR: 0.001000 | Time: 0.11 sec
# New best model found at epoch 386, saving checkpoint...
# Epoch 387 | Train Loss: 0.0054 | Test Loss: 0.0052 | LR: 0.001000 | Time: 0.12 sec
# New best model found at epoch 387, saving checkpoint...
# Epoch 388 | Train Loss: 0.0054 | Test Loss: 0.0051 | LR: 0.001000 | Time: 0.12 sec
# New best model found at epoch 388, saving checkpoint...
# Epoch 389 | Train Loss: 0.0054 | Test Loss: 0.0050 | LR: 0.001000 | Time: 0.11 sec
# New best model found at epoch 389, saving checkpoint...
# Epoch 390 | Train Loss: 0.0053 | Test Loss: 0.0049 | LR: 0.001000 | Time: 0.12 sec
# New best model found at epoch 390, saving checkpoint...
# Epoch 391 | Train Loss: 0.0053 | Test Loss: 0.0049 | LR: 0.001000 | Time: 0.13 sec
# New best model found at epoch 391, saving checkpoint...
# Epoch 392 | Train Loss: 0.0051 | Test Loss: 0.0048 | LR: 0.001000 | Time: 0.13 sec
# New best model found at epoch 392, saving checkpoint...
# Epoch 393 | Train Loss: 0.0050 | Test Loss: 0.0048 | LR: 0.001000 | Time: 0.12 sec
# New best model found at epoch 393, saving checkpoint...
# Epoch 394 | Train Loss: 0.0050 | Test Loss: 0.0047 | LR: 0.001000 | Time: 0.14 sec
# New best model found at epoch 394, saving checkpoint...
# Epoch 395 | Train Loss: 0.0050 | Test Loss: 0.0047 | LR: 0.001000 | Time: 0.12 sec
# New best model found at epoch 395, saving checkpoint...
# Epoch 396 | Train Loss: 0.0049 | Test Loss: 0.0046 | LR: 0.001000 | Time: 0.11 sec
# New best model found at epoch 396, saving checkpoint...
# Epoch 397 | Train Loss: 0.0049 | Test Loss: 0.0046 | LR: 0.001000 | Time: 0.11 sec
# New best model found at epoch 397, saving checkpoint...
# Epoch 398 | Train Loss: 0.0049 | Test Loss: 0.0045 | LR: 0.001000 | Time: 0.13 sec
# New best model found at epoch 398, saving checkpoint...
# Epoch 399 | Train Loss: 0.0049 | Test Loss: 0.0045 | LR: 0.001000 | Time: 0.15 sec
# New best model found at epoch 399, saving checkpoint...
# Epoch 400 | Train Loss: 0.0047 | Test Loss: 0.0044 | LR: 0.001000 | Time: 0.12 sec
# New best model found at epoch 400, saving checkpoint...
# Epoch 401 | Train Loss: 0.0048 | Test Loss: 0.0044 | LR: 0.001000 | Time: 0.13 sec
# New best model found at epoch 401, saving checkpoint...
# Epoch 402 | Train Loss: 0.0047 | Test Loss: 0.0044 | LR: 0.001000 | Time: 0.14 sec
# New best model found at epoch 402, saving checkpoint...
# Epoch 403 | Train Loss: 0.0046 | Test Loss: 0.0043 | LR: 0.001000 | Time: 0.14 sec
# New best model found at epoch 403, saving checkpoint...
# Epoch 404 | Train Loss: 0.0045 | Test Loss: 0.0043 | LR: 0.001000 | Time: 0.14 sec
# New best model found at epoch 404, saving checkpoint...
# Epoch 405 | Train Loss: 0.0046 | Test Loss: 0.0043 | LR: 0.001000 | Time: 0.11 sec
# New best model found at epoch 405, saving checkpoint...
# Epoch 406 | Train Loss: 0.0045 | Test Loss: 0.0042 | LR: 0.001000 | Time: 0.11 sec
# New best model found at epoch 406, saving checkpoint...
# Epoch 407 | Train Loss: 0.0045 | Test Loss: 0.0042 | LR: 0.001000 | Time: 0.13 sec
# New best model found at epoch 407, saving checkpoint...
# Epoch 408 | Train Loss: 0.0044 | Test Loss: 0.0041 | LR: 0.001000 | Time: 0.14 sec
# New best model found at epoch 408, saving checkpoint...
# Epoch 409 | Train Loss: 0.0044 | Test Loss: 0.0041 | LR: 0.001000 | Time: 0.13 sec
# New best model found at epoch 409, saving checkpoint...
# Epoch 410 | Train Loss: 0.0043 | Test Loss: 0.0041 | LR: 0.001000 | Time: 0.11 sec
# New best model found at epoch 410, saving checkpoint...
# Epoch 411 | Train Loss: 0.0044 | Test Loss: 0.0041 | LR: 0.001000 | Time: 0.11 sec
# New best model found at epoch 411, saving checkpoint...
# Epoch 412 | Train Loss: 0.0043 | Test Loss: 0.0040 | LR: 0.001000 | Time: 0.12 sec
# New best model found at epoch 412, saving checkpoint...
# Epoch 413 | Train Loss: 0.0043 | Test Loss: 0.0040 | LR: 0.001000 | Time: 0.13 sec
# New best model found at epoch 413, saving checkpoint...
# Epoch 414 | Train Loss: 0.0043 | Test Loss: 0.0040 | LR: 0.001000 | Time: 0.14 sec
# New best model found at epoch 414, saving checkpoint...
# Epoch 415 | Train Loss: 0.0042 | Test Loss: 0.0039 | LR: 0.001000 | Time: 0.13 sec
# New best model found at epoch 415, saving checkpoint...
# Epoch 416 | Train Loss: 0.0042 | Test Loss: 0.0039 | LR: 0.001000 | Time: 0.12 sec
# New best model found at epoch 416, saving checkpoint...
# Epoch 417 | Train Loss: 0.0042 | Test Loss: 0.0039 | LR: 0.001000 | Time: 0.12 sec
# New best model found at epoch 417, saving checkpoint...
# Epoch 418 | Train Loss: 0.0042 | Test Loss: 0.0039 | LR: 0.001000 | Time: 0.12 sec
# New best model found at epoch 418, saving checkpoint...
# Epoch 419 | Train Loss: 0.0042 | Test Loss: 0.0039 | LR: 0.001000 | Time: 0.12 sec
# New best model found at epoch 419, saving checkpoint...
# Epoch 420 | Train Loss: 0.0041 | Test Loss: 0.0038 | LR: 0.001000 | Time: 0.12 sec
# New best model found at epoch 420, saving checkpoint...
# Epoch 421 | Train Loss: 0.0040 | Test Loss: 0.0038 | LR: 0.001000 | Time: 0.13 sec
# New best model found at epoch 421, saving checkpoint...
# Epoch 422 | Train Loss: 0.0040 | Test Loss: 0.0038 | LR: 0.001000 | Time: 0.13 sec
# New best model found at epoch 422, saving checkpoint...
# Epoch 423 | Train Loss: 0.0040 | Test Loss: 0.0038 | LR: 0.001000 | Time: 0.13 sec
# New best model found at epoch 423, saving checkpoint...
# Epoch 424 | Train Loss: 0.0040 | Test Loss: 0.0037 | LR: 0.001000 | Time: 0.12 sec
# New best model found at epoch 424, saving checkpoint...
# Epoch 425 | Train Loss: 0.0039 | Test Loss: 0.0037 | LR: 0.001000 | Time: 0.14 sec
# New best model found at epoch 425, saving checkpoint...
# Epoch 426 | Train Loss: 0.0039 | Test Loss: 0.0037 | LR: 0.001000 | Time: 0.13 sec
# New best model found at epoch 426, saving checkpoint...
# Epoch 427 | Train Loss: 0.0040 | Test Loss: 0.0037 | LR: 0.001000 | Time: 0.12 sec
# New best model found at epoch 427, saving checkpoint...
# Epoch 428 | Train Loss: 0.0039 | Test Loss: 0.0036 | LR: 0.001000 | Time: 0.15 sec
# New best model found at epoch 428, saving checkpoint...
# Epoch 429 | Train Loss: 0.0038 | Test Loss: 0.0036 | LR: 0.001000 | Time: 0.15 sec
# New best model found at epoch 429, saving checkpoint...
# Epoch 430 | Train Loss: 0.0039 | Test Loss: 0.0036 | LR: 0.001000 | Time: 0.14 sec
# New best model found at epoch 430, saving checkpoint...
# Epoch 431 | Train Loss: 0.0039 | Test Loss: 0.0036 | LR: 0.001000 | Time: 0.12 sec
# New best model found at epoch 431, saving checkpoint...
# Epoch 432 | Train Loss: 0.0038 | Test Loss: 0.0035 | LR: 0.001000 | Time: 0.13 sec
# New best model found at epoch 432, saving checkpoint...
# Epoch 433 | Train Loss: 0.0038 | Test Loss: 0.0035 | LR: 0.001000 | Time: 0.12 sec
# New best model found at epoch 433, saving checkpoint...
# Epoch 434 | Train Loss: 0.0038 | Test Loss: 0.0035 | LR: 0.001000 | Time: 0.14 sec
# New best model found at epoch 434, saving checkpoint...
# Epoch 435 | Train Loss: 0.0038 | Test Loss: 0.0035 | LR: 0.001000 | Time: 0.11 sec
# New best model found at epoch 435, saving checkpoint...
# Epoch 436 | Train Loss: 0.0037 | Test Loss: 0.0035 | LR: 0.001000 | Time: 0.13 sec
# New best model found at epoch 436, saving checkpoint...
# Epoch 437 | Train Loss: 0.0037 | Test Loss: 0.0035 | LR: 0.001000 | Time: 0.12 sec
# New best model found at epoch 437, saving checkpoint...
# Epoch 438 | Train Loss: 0.0037 | Test Loss: 0.0034 | LR: 0.001000 | Time: 0.12 sec
# New best model found at epoch 438, saving checkpoint...
# Epoch 439 | Train Loss: 0.0036 | Test Loss: 0.0034 | LR: 0.001000 | Time: 0.12 sec
# New best model found at epoch 439, saving checkpoint...
# Epoch 440 | Train Loss: 0.0036 | Test Loss: 0.0034 | LR: 0.001000 | Time: 0.12 sec
# New best model found at epoch 440, saving checkpoint...
# Epoch 441 | Train Loss: 0.0037 | Test Loss: 0.0034 | LR: 0.001000 | Time: 0.13 sec
# New best model found at epoch 441, saving checkpoint...
# Epoch 442 | Train Loss: 0.0036 | Test Loss: 0.0034 | LR: 0.001000 | Time: 0.13 sec
# Epoch 443 | Train Loss: 0.0037 | Test Loss: 0.0034 | LR: 0.001000 | Time: 0.12 sec
# New best model found at epoch 443, saving checkpoint...
# Epoch 444 | Train Loss: 0.0036 | Test Loss: 0.0033 | LR: 0.001000 | Time: 0.12 sec
# New best model found at epoch 444, saving checkpoint...
# Epoch 445 | Train Loss: 0.0035 | Test Loss: 0.0033 | LR: 0.001000 | Time: 0.82 sec
# New best model found at epoch 445, saving checkpoint...
# Epoch 446 | Train Loss: 0.0036 | Test Loss: 0.0033 | LR: 0.001000 | Time: 0.13 sec
# New best model found at epoch 446, saving checkpoint...
# Epoch 447 | Train Loss: 0.0036 | Test Loss: 0.0033 | LR: 0.001000 | Time: 0.12 sec
# New best model found at epoch 447, saving checkpoint...
# Epoch 448 | Train Loss: 0.0035 | Test Loss: 0.0033 | LR: 0.001000 | Time: 0.14 sec
# New best model found at epoch 448, saving checkpoint...
# Epoch 449 | Train Loss: 0.0036 | Test Loss: 0.0033 | LR: 0.001000 | Time: 0.13 sec
# New best model found at epoch 449, saving checkpoint...
# Epoch 450 | Train Loss: 0.0035 | Test Loss: 0.0032 | LR: 0.001000 | Time: 0.13 sec
# New best model found at epoch 450, saving checkpoint...
# Epoch 451 | Train Loss: 0.0036 | Test Loss: 0.0032 | LR: 0.001000 | Time: 0.13 sec
# New best model found at epoch 451, saving checkpoint...
# Epoch 452 | Train Loss: 0.0035 | Test Loss: 0.0032 | LR: 0.001000 | Time: 0.12 sec
# New best model found at epoch 452, saving checkpoint...
# Epoch 453 | Train Loss: 0.0034 | Test Loss: 0.0032 | LR: 0.001000 | Time: 0.13 sec
# New best model found at epoch 453, saving checkpoint...
# Epoch 454 | Train Loss: 0.0035 | Test Loss: 0.0032 | LR: 0.001000 | Time: 0.11 sec
# New best model found at epoch 454, saving checkpoint...
# Epoch 455 | Train Loss: 0.0035 | Test Loss: 0.0032 | LR: 0.001000 | Time: 0.12 sec
# New best model found at epoch 455, saving checkpoint...
# Epoch 456 | Train Loss: 0.0035 | Test Loss: 0.0031 | LR: 0.001000 | Time: 0.12 sec
# New best model found at epoch 456, saving checkpoint...
# Epoch 457 | Train Loss: 0.0034 | Test Loss: 0.0031 | LR: 0.001000 | Time: 0.12 sec
# New best model found at epoch 457, saving checkpoint...
# Epoch 458 | Train Loss: 0.0034 | Test Loss: 0.0031 | LR: 0.001000 | Time: 0.13 sec
# Epoch 459 | Train Loss: 0.0034 | Test Loss: 0.0031 | LR: 0.001000 | Time: 0.13 sec
# New best model found at epoch 459, saving checkpoint...
# Epoch 460 | Train Loss: 0.0034 | Test Loss: 0.0031 | LR: 0.001000 | Time: 0.12 sec
# New best model found at epoch 460, saving checkpoint...
# Epoch 461 | Train Loss: 0.0034 | Test Loss: 0.0031 | LR: 0.001000 | Time: 0.14 sec
# New best model found at epoch 461, saving checkpoint...
# Epoch 462 | Train Loss: 0.0034 | Test Loss: 0.0031 | LR: 0.001000 | Time: 0.12 sec
# New best model found at epoch 462, saving checkpoint...
# Epoch 463 | Train Loss: 0.0033 | Test Loss: 0.0030 | LR: 0.001000 | Time: 0.12 sec
# New best model found at epoch 463, saving checkpoint...
# Epoch 464 | Train Loss: 0.0033 | Test Loss: 0.0030 | LR: 0.001000 | Time: 0.13 sec
# New best model found at epoch 464, saving checkpoint...
# Epoch 465 | Train Loss: 0.0033 | Test Loss: 0.0030 | LR: 0.001000 | Time: 0.13 sec
# New best model found at epoch 465, saving checkpoint...
# Epoch 466 | Train Loss: 0.0033 | Test Loss: 0.0030 | LR: 0.001000 | Time: 0.12 sec
# New best model found at epoch 466, saving checkpoint...
# Epoch 467 | Train Loss: 0.0033 | Test Loss: 0.0030 | LR: 0.001000 | Time: 0.12 sec
# New best model found at epoch 467, saving checkpoint...
# Epoch 468 | Train Loss: 0.0033 | Test Loss: 0.0030 | LR: 0.001000 | Time: 0.15 sec
# New best model found at epoch 468, saving checkpoint...
# Epoch 469 | Train Loss: 0.0032 | Test Loss: 0.0030 | LR: 0.001000 | Time: 0.12 sec
# New best model found at epoch 469, saving checkpoint...
# Epoch 470 | Train Loss: 0.0032 | Test Loss: 0.0029 | LR: 0.001000 | Time: 0.13 sec
# New best model found at epoch 470, saving checkpoint...
# Epoch 471 | Train Loss: 0.0032 | Test Loss: 0.0029 | LR: 0.001000 | Time: 0.13 sec
# New best model found at epoch 471, saving checkpoint...
# Epoch 472 | Train Loss: 0.0032 | Test Loss: 0.0029 | LR: 0.001000 | Time: 0.14 sec
# New best model found at epoch 472, saving checkpoint...
# Epoch 473 | Train Loss: 0.0032 | Test Loss: 0.0029 | LR: 0.001000 | Time: 0.13 sec
# New best model found at epoch 473, saving checkpoint...
# Epoch 474 | Train Loss: 0.0032 | Test Loss: 0.0029 | LR: 0.001000 | Time: 0.15 sec
# New best model found at epoch 474, saving checkpoint...
# Epoch 475 | Train Loss: 0.0032 | Test Loss: 0.0029 | LR: 0.001000 | Time: 0.12 sec
# New best model found at epoch 475, saving checkpoint...
# Epoch 476 | Train Loss: 0.0031 | Test Loss: 0.0029 | LR: 0.001000 | Time: 0.13 sec
# New best model found at epoch 476, saving checkpoint...
# Epoch 477 | Train Loss: 0.0032 | Test Loss: 0.0028 | LR: 0.001000 | Time: 0.15 sec
# New best model found at epoch 477, saving checkpoint...
# Epoch 478 | Train Loss: 0.0031 | Test Loss: 0.0028 | LR: 0.001000 | Time: 0.13 sec
# New best model found at epoch 478, saving checkpoint...
# Epoch 479 | Train Loss: 0.0031 | Test Loss: 0.0028 | LR: 0.001000 | Time: 0.19 sec
# New best model found at epoch 479, saving checkpoint...
# Epoch 480 | Train Loss: 0.0031 | Test Loss: 0.0028 | LR: 0.001000 | Time: 0.13 sec
# Epoch 481 | Train Loss: 0.0031 | Test Loss: 0.0028 | LR: 0.001000 | Time: 0.12 sec
# New best model found at epoch 481, saving checkpoint...
# Epoch 482 | Train Loss: 0.0031 | Test Loss: 0.0028 | LR: 0.001000 | Time: 0.13 sec
# New best model found at epoch 482, saving checkpoint...
# Epoch 483 | Train Loss: 0.0031 | Test Loss: 0.0028 | LR: 0.001000 | Time: 0.12 sec
# New best model found at epoch 483, saving checkpoint...
# Epoch 484 | Train Loss: 0.0031 | Test Loss: 0.0027 | LR: 0.001000 | Time: 0.12 sec
# New best model found at epoch 484, saving checkpoint...
# Epoch 485 | Train Loss: 0.0031 | Test Loss: 0.0027 | LR: 0.001000 | Time: 0.13 sec
# Epoch 486 | Train Loss: 0.0030 | Test Loss: 0.0027 | LR: 0.001000 | Time: 0.13 sec
# New best model found at epoch 486, saving checkpoint...
# Epoch 487 | Train Loss: 0.0030 | Test Loss: 0.0027 | LR: 0.001000 | Time: 0.13 sec
# New best model found at epoch 487, saving checkpoint...
# Epoch 488 | Train Loss: 0.0030 | Test Loss: 0.0027 | LR: 0.001000 | Time: 0.17 sec
# New best model found at epoch 488, saving checkpoint...
# Epoch 489 | Train Loss: 0.0030 | Test Loss: 0.0027 | LR: 0.001000 | Time: 0.14 sec
# New best model found at epoch 489, saving checkpoint...
# Epoch 490 | Train Loss: 0.0030 | Test Loss: 0.0027 | LR: 0.001000 | Time: 0.16 sec
# New best model found at epoch 490, saving checkpoint...
# Epoch 491 | Train Loss: 0.0030 | Test Loss: 0.0026 | LR: 0.001000 | Time: 0.15 sec
# New best model found at epoch 491, saving checkpoint...
# Epoch 492 | Train Loss: 0.0029 | Test Loss: 0.0026 | LR: 0.001000 | Time: 0.14 sec
# New best model found at epoch 492, saving checkpoint...
# Epoch 493 | Train Loss: 0.0029 | Test Loss: 0.0026 | LR: 0.001000 | Time: 0.13 sec
# New best model found at epoch 493, saving checkpoint...
# Epoch 494 | Train Loss: 0.0029 | Test Loss: 0.0026 | LR: 0.001000 | Time: 0.12 sec
# New best model found at epoch 494, saving checkpoint...
# Epoch 495 | Train Loss: 0.0029 | Test Loss: 0.0026 | LR: 0.001000 | Time: 0.12 sec
# New best model found at epoch 495, saving checkpoint...
# Epoch 496 | Train Loss: 0.0029 | Test Loss: 0.0026 | LR: 0.001000 | Time: 0.14 sec
# New best model found at epoch 496, saving checkpoint...
# Epoch 497 | Train Loss: 0.0028 | Test Loss: 0.0026 | LR: 0.001000 | Time: 0.14 sec
# New best model found at epoch 497, saving checkpoint...
# Epoch 498 | Train Loss: 0.0029 | Test Loss: 0.0026 | LR: 0.001000 | Time: 0.12 sec
# New best model found at epoch 498, saving checkpoint...
# Epoch 499 | Train Loss: 0.0029 | Test Loss: 0.0025 | LR: 0.001000 | Time: 0.14 sec
# New best model found at epoch 499, saving checkpoint...
# Epoch 500 | Train Loss: 0.0028 | Test Loss: 0.0025 | LR: 0.001000 | Time: 0.13 sec
# New best model found at epoch 500, saving checkpoint...

# %% [markdown]
# ## Run Tensorboard to inspect results
#
# To run Tensorboard, you may run it from the same directory as this notebook. You may run the following command either during or after the training run:
#
# ```
# tensorboard --logdir=runs
# ```
#
# Make sure you activated the appropriate virtual environment which has tensorboard installed.
#
# You should see the following:
#
# ```
# Serving TensorBoard on localhost; to expose to the network, use a proxy or pass --bind_all
# TensorBoard 2.20.0 at http://localhost:6006/ (Press CTRL+C to quit)
# ```
#
# and you may use a browser to access tensorboard via the URL above.

# %%
plt.figure(figsize=(8, 5))
plt.plot(train_losses, label="Train Loss")
plt.plot(test_losses, label="Test Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss (MSE)")
plt.title("Training and Test Loss Over Epochs")
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.savefig("loss_curve.png", dpi=300)

# %% [markdown]
# # Get embedding vector from encoder side of the model

# %%
with torch.no_grad():
    x_tensor = torch.tensor(X_test, dtype=torch.float32).to(device)
    embeddings = model.encoder(x_tensor)  # Shape: [n_samples, latent_dim]

# %%
embeddings.shape
# Out:
# torch.Size([178, 8])

# %%
embedding_df = pd.DataFrame(embeddings.cpu().numpy(), columns=[f"embeddings{i}" for i in range(embeddings.shape[1])])
embedding_df.to_csv("titanic_latent_embeddings.csv", index=False)

# %%
## More later
